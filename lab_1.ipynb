# %%
import json
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

# %%
f = open('../js/metro.json', 'r')
lines = json.load(f)['lines']
f.close()
lines
# Out:
# [{'id': 0,
#   'number': '01',
#   'title': 'Сокольническая линия',
#   'hexColor': 'EF161E',
#   'stations': [{'id': 0,
#     'order': 0,
#     'title': 'Бульвар Рокоссовского',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Бульвар Рокоссовского Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 248,
#       'order': 5,
#       'title': 'Бульвар Рокоссовского'}],
#     'pos': {'lat': '37.735117', 'lng': '55.814264'}},
#    {'id': 1,
#     'order': 1,
#     'title': 'Черкизовская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Локомотив Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 249, 'order': 6, 'title': 'Локомотив'}],
#     'pos': {'lat': '37.744927', 'lng': '55.803671'}},
#    {'id': 2,
#     'order': 2,
#     'title': 'Преображенская площадь',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.715022', 'lng': '55.796167'}},
#    {'id': 3,
#     'order': 3,
#     'title': 'Сокольники',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.67988', 'lng': '55.788991'}},
#    {'id': 4,
#     'order': 4,
#     'title': 'Красносельская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.666225', 'lng': '55.779818'}},
#    {'id': 5,
#     'order': 5,
#     'title': 'Комсомольская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Комсомольская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 90, 'order': 6, 'title': 'Комсомольская'}],
#     'pos': {'lat': '37.653846', 'lng': '55.77435'}},
#    {'id': 6,
#     'order': 6,
#     'title': 'Красные Ворота',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.64922', 'lng': '55.768659'}},
#    {'id': 7,
#     'order': 7,
#     'title': 'Чистые пруды',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Тургеневская Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'},
#      {'number': '10',
#       'str': 'Переход на станцию Сретенский бульвар Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 104, 'order': 8, 'title': 'Тургеневская'},
#      {'id': 195, 'order': 9, 'title': 'Сретенский бульвар'}],
#     'pos': {'lat': '37.638683', 'lng': '55.764794'}},
#    {'id': 8,
#     'order': 8,
#     'title': 'Лубянка',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Кузнецкий Мост Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 130, 'order': 11, 'title': 'Кузнецкий Мост'}],
#     'pos': {'lat': '37.626789', 'lng': '55.759456'}},
#    {'id': 9,
#     'order': 9,
#     'title': 'Охотный Ряд',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Театральная Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'},
#      {'number': '03',
#       'str': 'Переход на станцию Площадь Революции Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'}],
#     'transferToStation': [{'id': 37, 'order': 11, 'title': 'Театральная'},
#      {'id': 62, 'order': 12, 'title': 'Площадь Революции'}],
#     'pos': {'lat': '37.615524', 'lng': '55.756964'}},
#    {'id': 10,
#     'order': 10,
#     'title': 'Библиотека имени Ленина',
#     'transferToLine': [{'number': '03',
#       'str': 'Переход на станцию Арбатская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'},
#      {'number': '04',
#       'str': 'Переход на станцию Александровский сад Филёвской линии',
#       'title': 'Филёвская линия'},
#      {'number': '09',
#       'str': 'Переход на станцию Боровицкая Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 61, 'order': 11, 'title': 'Арбатская'},
#      {'id': 83, 'order': 12, 'title': 'Александровский сад'},
#      {'id': 172, 'order': 11, 'title': 'Боровицкая'}],
#     'pos': {'lat': '37.610107', 'lng': '55.751315'}},
#    {'id': 11,
#     'order': 11,
#     'title': 'Кропоткинская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.603487', 'lng': '55.745068'}},
#    {'id': 12,
#     'order': 12,
#     'title': 'Парк культуры',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Парк культуры Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 84, 'order': 0, 'title': 'Парк культуры'}],
#     'pos': {'lat': '37.594683', 'lng': '55.735819'}},
#    {'id': 13,
#     'order': 13,
#     'title': 'Фрунзенская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.580463', 'lng': '55.727313'}},
#    {'id': 14,
#     'order': 14,
#     'title': 'Спортивная',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Лужники Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 263, 'order': 20, 'title': 'Лужники'}],
#     'pos': {'lat': '37.564105', 'lng': '55.723247'}},
#    {'id': 15,
#     'order': 15,
#     'title': 'Воробьёвы горы',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.559317', 'lng': '55.710438'}},
#    {'id': 16,
#     'order': 16,
#     'title': 'Университет',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.533517', 'lng': '55.692612'}},
#    {'id': 17,
#     'order': 17,
#     'title': 'Проспект Вернадского',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.505831', 'lng': '55.67691'}},
#    {'id': 18,
#     'order': 18,
#     'title': 'Юго-Западная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.483095', 'lng': '55.663629'}},
#    {'id': 19,
#     'order': 19,
#     'title': 'Тропарёво',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.472378', 'lng': '55.64574'}},
#    {'id': 20,
#     'order': 20,
#     'title': 'Румянцево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.441395', 'lng': '55.633028'}},
#    {'id': 21,
#     'order': 21,
#     'title': 'Саларьево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.424048', 'lng': '55.621811'}},
#    {'id': 22,
#     'order': 22,
#     'title': 'Филатов луг',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.407995', 'lng': '55.601177'}},
#    {'id': 23,
#     'order': 23,
#     'title': 'Прокшино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.43322', 'lng': '55.586456'}},
#    {'id': 24,
#     'order': 24,
#     'title': 'Ольховая',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.459047', 'lng': '55.56898'}},
#    {'id': 25,
#     'order': 25,
#     'title': 'Коммунарка',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.46865', 'lng': '55.560071'}}]},
#  {'id': 1,
#   'number': '02',
#   'title': 'Замоскворецкая линия',
#   'hexColor': '2DBE2C',
#   'stations': [{'id': 26,
#     'order': 0,
#     'title': 'Ховрино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.480768', 'lng': '55.878273'}},
#    {'id': 27,
#     'order': 1,
#     'title': 'Беломорская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.475692', 'lng': '55.865369'}},
#    {'id': 28,
#     'order': 2,
#     'title': 'Речной вокзал',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.476231', 'lng': '55.854891'}},
#    {'id': 29,
#     'order': 3,
#     'title': 'Водный стадион',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.486769', 'lng': '55.839881'}},
#    {'id': 30,
#     'order': 4,
#     'title': 'Войковская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Балтийская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'},
#      {'number': '14',
#       'str': 'Переход на станцию Стрешнево Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 271, 'order': 28, 'title': 'Балтийская'},
#      {'id': 270, 'order': 27, 'title': 'Стрешнево'}],
#     'pos': {'lat': '37.497791', 'lng': '55.818923'}},
#    {'id': 31,
#     'order': 5,
#     'title': 'Сокол',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.514787', 'lng': '55.805042'}},
#    {'id': 32,
#     'order': 6,
#     'title': 'Аэропорт',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.531765', 'lng': '55.800979'}},
#    {'id': 33,
#     'order': 7,
#     'title': 'Динамо',
#     'transferToLine': [{'number': '8А',
#       'str': 'Переход на станцию Петровский парк Солнцевской линии',
#       'title': 'Солнцевская линия'},
#      {'number': '11',
#       'str': 'Переход на станцию Петровский парк Большой кольцевой линии',
#       'title': 'Большая кольцевая линия'}],
#     'transferToStation': [{'id': 216, 'order': 14, 'title': 'Петровский парк'},
#      {'id': 217, 'order': 4, 'title': 'Петровский парк'}],
#     'pos': {'lat': '37.558212', 'lng': '55.789704'}},
#    {'id': 34,
#     'order': 8,
#     'title': 'Белорусская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Белорусская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 93, 'order': 9, 'title': 'Белорусская'}],
#     'pos': {'lat': '37.582206', 'lng': '55.777388'}},
#    {'id': 35,
#     'order': 9,
#     'title': 'Маяковская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.595914', 'lng': '55.76996'}},
#    {'id': 36,
#     'order': 10,
#     'title': 'Тверская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Пушкинская Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'},
#      {'number': '09',
#       'str': 'Переход на станцию Чеховская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 129, 'order': 10, 'title': 'Пушкинская'},
#      {'id': 171, 'order': 10, 'title': 'Чеховская'}],
#     'pos': {'lat': '37.605939', 'lng': '55.764455'}},
#    {'id': 37,
#     'order': 11,
#     'title': 'Театральная',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Охотный Ряд Сокольнической линии',
#       'title': 'Сокольническая линия'},
#      {'number': '03',
#       'str': 'Переход на станцию Площадь Революции Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'}],
#     'transferToStation': [{'id': 9, 'order': 9, 'title': 'Охотный Ряд'},
#      {'id': 62, 'order': 12, 'title': 'Площадь Революции'}],
#     'pos': {'lat': '37.619001', 'lng': '55.757967'}},
#    {'id': 38,
#     'order': 12,
#     'title': 'Новокузнецкая',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Третьяковская Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'},
#      {'number': '08',
#       'str': 'Переход на станцию Третьяковская Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 106, 'order': 10, 'title': 'Третьяковская'},
#      {'id': 153, 'order': 0, 'title': 'Третьяковская'}],
#     'pos': {'lat': '37.629232', 'lng': '55.742372'}},
#    {'id': 39,
#     'order': 13,
#     'title': 'Павелецкая',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Павелецкая Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 87, 'order': 3, 'title': 'Павелецкая'}],
#     'pos': {'lat': '37.638557', 'lng': '55.729878'}},
#    {'id': 40,
#     'order': 14,
#     'title': 'Автозаводская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Автозаводская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 258, 'order': 15, 'title': 'Автозаводская'}],
#     'pos': {'lat': '37.657646', 'lng': '55.707182'}},
#    {'id': 41,
#     'order': 15,
#     'title': 'Технопарк',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.66442', 'lng': '55.693931'}},
#    {'id': 42,
#     'order': 16,
#     'title': 'Коломенская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.663827', 'lng': '55.678407'}},
#    {'id': 43,
#     'order': 17,
#     'title': 'Каширская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.648798', 'lng': '55.655107'}},
#    {'id': 44,
#     'order': 18,
#     'title': 'Кантемировская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.656218', 'lng': '55.636107'}},
#    {'id': 45,
#     'order': 19,
#     'title': 'Царицыно',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.669028', 'lng': '55.621653'}},
#    {'id': 46,
#     'order': 20,
#     'title': 'Орехово',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.695331', 'lng': '55.612884'}},
#    {'id': 47,
#     'order': 21,
#     'title': 'Домодедовская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.718552', 'lng': '55.610814'}},
#    {'id': 48,
#     'order': 22,
#     'title': 'Красногвардейская',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Зябликово Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 208, 'order': 22, 'title': 'Зябликово'}],
#     'pos': {'lat': '37.744055', 'lng': '55.613605'}},
#    {'id': 49,
#     'order': 23,
#     'title': 'Алма-Атинская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.765911', 'lng': '55.63282'}}]},
#  {'id': 2,
#   'number': '03',
#   'title': 'Арбатско-Покровская линия',
#   'hexColor': '0078BE',
#   'stations': [{'id': 50,
#     'order': 0,
#     'title': 'Пятницкое шоссе',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.354132', 'lng': '55.855967'}},
#    {'id': 51,
#     'order': 1,
#     'title': 'Митино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.362154', 'lng': '55.845734'}},
#    {'id': 52,
#     'order': 2,
#     'title': 'Волоколамская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.382034', 'lng': '55.835508'}},
#    {'id': 53,
#     'order': 3,
#     'title': 'Мякинино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.385331', 'lng': '55.82489'}},
#    {'id': 54,
#     'order': 4,
#     'title': 'Строгино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.403118', 'lng': '55.803691'}},
#    {'id': 55,
#     'order': 5,
#     'title': 'Крылатское',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.408139', 'lng': '55.756842'}},
#    {'id': 56,
#     'order': 6,
#     'title': 'Молодёжная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.416619', 'lng': '55.740867'}},
#    {'id': 57,
#     'order': 7,
#     'title': 'Кунцевская',
#     'transferToLine': [{'number': '04',
#       'str': 'Кросс-платформенная пересадка на станцию Кунцевская Филёвской линии',
#       'title': 'Филёвская линия'}],
#     'transferToStation': [{'id': 71, 'order': 0, 'title': 'Кунцевская'}],
#     'pos': {'lat': '37.445437', 'lng': '55.730603'}},
#    {'id': 58,
#     'order': 8,
#     'title': 'Славянский бульвар',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.470572', 'lng': '55.729574'}},
#    {'id': 59,
#     'order': 9,
#     'title': 'Парк Победы',
#     'transferToLine': [{'number': '8А',
#       'str': 'Кросс-платформенная пересадка на станцию Парк Победы Солнцевской линии',
#       'title': 'Солнцевская линия'}],
#     'transferToStation': [{'id': 152, 'order': 10, 'title': 'Парк Победы'}],
#     'pos': {'lat': '37.516009', 'lng': '55.736934'}},
#    {'id': 60,
#     'order': 10,
#     'title': 'Киевская',
#     'transferToLine': [{'number': '04',
#       'str': 'Переход на станцию Киевская Филёвской линии',
#       'title': 'Филёвская линия'},
#      {'number': '05',
#       'str': 'Переход на станцию Киевская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 80, 'order': 9, 'title': 'Киевская'},
#      {'id': 95, 'order': 11, 'title': 'Киевская'}],
#     'pos': {'lat': '37.566809', 'lng': '55.744698'}},
#    {'id': 61,
#     'order': 11,
#     'title': 'Арбатская',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Библиотека имени Ленина Сокольнической линии',
#       'title': 'Сокольническая линия'},
#      {'number': '04',
#       'str': 'Переход на станцию Александровский сад Филёвской линии',
#       'title': 'Филёвская линия'},
#      {'number': '09',
#       'str': 'Переход на станцию Боровицкая Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 10,
#       'order': 10,
#       'title': 'Библиотека имени Ленина'},
#      {'id': 83, 'order': 12, 'title': 'Александровский сад'},
#      {'id': 172, 'order': 11, 'title': 'Боровицкая'}],
#     'pos': {'lat': '37.604196', 'lng': '55.752536'}},
#    {'id': 62,
#     'order': 12,
#     'title': 'Площадь Революции',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Охотный Ряд Сокольнической линии',
#       'title': 'Сокольническая линия'},
#      {'number': '02',
#       'str': 'Переход на станцию Театральная Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 9, 'order': 9, 'title': 'Охотный Ряд'},
#      {'id': 37, 'order': 11, 'title': 'Театральная'}],
#     'pos': {'lat': '37.62272', 'lng': '55.756802'}},
#    {'id': 63,
#     'order': 13,
#     'title': 'Курская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Курская Кольцевой линии',
#       'title': 'Кольцевая линия'},
#      {'number': '10',
#       'str': 'Переход на станцию Чкаловская Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 89, 'order': 5, 'title': 'Курская'},
#      {'id': 196, 'order': 10, 'title': 'Чкаловская'}],
#     'pos': {'lat': '37.65876', 'lng': '55.758524'}},
#    {'id': 64,
#     'order': 14,
#     'title': 'Бауманская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.679035', 'lng': '55.772406'}},
#    {'id': 65,
#     'order': 15,
#     'title': 'Электрозаводская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.705284', 'lng': '55.782066'}},
#    {'id': 66,
#     'order': 16,
#     'title': 'Семёновская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.719423', 'lng': '55.783195'}},
#    {'id': 67,
#     'order': 17,
#     'title': 'Партизанская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Измайлово Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 250, 'order': 7, 'title': 'Измайлово'}],
#     'pos': {'lat': '37.749265', 'lng': '55.788424'}},
#    {'id': 68,
#     'order': 18,
#     'title': 'Измайловская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.781497', 'lng': '55.787761'}},
#    {'id': 69,
#     'order': 19,
#     'title': 'Первомайская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.799418', 'lng': '55.794614'}},
#    {'id': 70,
#     'order': 20,
#     'title': 'Щёлковская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.798583', 'lng': '55.809712'}}]},
#  {'id': 3,
#   'number': '04',
#   'title': 'Филёвская линия',
#   'hexColor': '00BFFF',
#   'stations': [{'id': 71,
#     'order': 0,
#     'title': 'Кунцевская',
#     'transferToLine': [{'number': '03',
#       'str': 'Кросс-платформенная пересадка на станцию Кунцевская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'}],
#     'transferToStation': [{'id': 57, 'order': 7, 'title': 'Кунцевская'}],
#     'pos': {'lat': '37.446488', 'lng': '55.730862'}},
#    {'id': 72,
#     'order': 1,
#     'title': 'Пионерская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.467078', 'lng': '55.735986'}},
#    {'id': 73,
#     'order': 2,
#     'title': 'Филёвский парк',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.483328', 'lng': '55.739519'}},
#    {'id': 74,
#     'order': 3,
#     'title': 'Багратионовская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.497863', 'lng': '55.743801'}},
#    {'id': 75,
#     'order': 4,
#     'title': 'Фили',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.514949', 'lng': '55.74597'}},
#    {'id': 76,
#     'order': 5,
#     'title': 'Кутузовская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Кутузовская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 264, 'order': 21, 'title': 'Кутузовская'}],
#     'pos': {'lat': '37.534191', 'lng': '55.74033'}},
#    {'id': 77,
#     'order': 6,
#     'title': 'Студенческая',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.548375', 'lng': '55.738784'}},
#    {'id': 78,
#     'order': 7,
#     'title': 'Международная',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Деловой центр Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 265, 'order': 22, 'title': 'Деловой центр'}],
#     'pos': {'lat': '37.534263', 'lng': '55.748311'}},
#    {'id': 79,
#     'order': 8,
#     'title': 'Выставочная',
#     'transferToLine': [{'number': '8А',
#       'str': 'Переход на станцию Деловой центр Солнцевской линии',
#       'title': 'Солнцевская линия'},
#      {'number': '11',
#       'str': 'Переход на станцию Деловой центр Большой кольцевой линии',
#       'title': 'Большая кольцевая линия'}],
#     'transferToStation': [{'id': 209, 'order': 0, 'title': 'Деловой центр'}],
#     'pos': {'lat': '37.541386', 'lng': '55.750074'}},
#    {'id': 80,
#     'order': 9,
#     'title': 'Киевская',
#     'transferToLine': [{'number': '03',
#       'str': 'Переход на станцию Киевская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'},
#      {'number': '05',
#       'str': 'Переход на станцию Киевская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 60, 'order': 10, 'title': 'Киевская'},
#      {'id': 95, 'order': 11, 'title': 'Киевская'}],
#     'pos': {'lat': '37.565587', 'lng': '55.743588'}},
#    {'id': 81,
#     'order': 10,
#     'title': 'Смоленская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.582161', 'lng': '55.748756'}},
#    {'id': 82,
#     'order': 11,
#     'title': 'Арбатская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.601358', 'lng': '55.75207'}},
#    {'id': 83,
#     'order': 12,
#     'title': 'Александровский сад',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Библиотека имени Ленина Сокольнической линии',
#       'title': 'Сокольническая линия'},
#      {'number': '03',
#       'str': 'Переход на станцию Арбатская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'},
#      {'number': '09',
#       'str': 'Переход на станцию Боровицкая Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 10,
#       'order': 10,
#       'title': 'Библиотека имени Ленина'},
#      {'id': 61, 'order': 11, 'title': 'Арбатская'},
#      {'id': 172, 'order': 11, 'title': 'Боровицкая'}],
#     'pos': {'lat': '37.609461', 'lng': '55.752349'}}]},
#  {'id': 4,
#   'number': '05',
#   'title': 'Кольцевая линия',
#   'hexColor': '8D5B2D',
#   'stations': [{'id': 84,
#     'order': 0,
#     'title': 'Парк культуры',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Парк культуры Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 12, 'order': 12, 'title': 'Парк культуры'}],
#     'pos': {'lat': '37.592869', 'lng': '55.735302'}},
#    {'id': 85,
#     'order': 1,
#     'title': 'Октябрьская',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Октябрьская Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 107, 'order': 11, 'title': 'Октябрьская'}],
#     'pos': {'lat': '37.611096', 'lng': '55.729275'}},
#    {'id': 86,
#     'order': 2,
#     'title': 'Добрынинская',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Серпуховская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 174, 'order': 13, 'title': 'Серпуховская'}],
#     'pos': {'lat': '37.622513', 'lng': '55.729006'}},
#    {'id': 87,
#     'order': 3,
#     'title': 'Павелецкая',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Павелецкая Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 39, 'order': 13, 'title': 'Павелецкая'}],
#     'pos': {'lat': '37.637003', 'lng': '55.73182'}},
#    {'id': 88,
#     'order': 4,
#     'title': 'Таганская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Таганская Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'},
#      {'number': '08',
#       'str': 'Переход на станцию Марксистская Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 132, 'order': 13, 'title': 'Таганская'},
#      {'id': 154, 'order': 1, 'title': 'Марксистская'}],
#     'pos': {'lat': '37.653128', 'lng': '55.742423'}},
#    {'id': 89,
#     'order': 5,
#     'title': 'Курская',
#     'transferToLine': [{'number': '03',
#       'str': 'Переход на станцию Курская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'},
#      {'number': '10',
#       'str': 'Переход на станцию Чкаловская Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 63, 'order': 13, 'title': 'Курская'},
#      {'id': 196, 'order': 10, 'title': 'Чкаловская'}],
#     'pos': {'lat': '37.659937', 'lng': '55.75745'}},
#    {'id': 90,
#     'order': 6,
#     'title': 'Комсомольская',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Комсомольская Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 5, 'order': 5, 'title': 'Комсомольская'}],
#     'pos': {'lat': '37.6547', 'lng': '55.775707'}},
#    {'id': 91,
#     'order': 7,
#     'title': 'Проспект Мира',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Проспект Мира Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 102, 'order': 6, 'title': 'Проспект Мира'}],
#     'pos': {'lat': '37.633464', 'lng': '55.779631'}},
#    {'id': 92,
#     'order': 8,
#     'title': 'Новослободская',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Менделеевская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 169, 'order': 8, 'title': 'Менделеевская'}],
#     'pos': {'lat': '37.601421', 'lng': '55.779565'}},
#    {'id': 93,
#     'order': 9,
#     'title': 'Белорусская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Белорусская Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 34, 'order': 8, 'title': 'Белорусская'}],
#     'pos': {'lat': '37.585251', 'lng': '55.776775'}},
#    {'id': 94,
#     'order': 10,
#     'title': 'Краснопресненская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Баррикадная Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 128, 'order': 9, 'title': 'Баррикадная'}],
#     'pos': {'lat': '37.577211', 'lng': '55.760211'}},
#    {'id': 95,
#     'order': 11,
#     'title': 'Киевская',
#     'transferToLine': [{'number': '03',
#       'str': 'Переход на станцию Киевская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'},
#      {'number': '04',
#       'str': 'Переход на станцию Киевская Филёвской линии',
#       'title': 'Филёвская линия'}],
#     'transferToStation': [{'id': 60, 'order': 10, 'title': 'Киевская'},
#      {'id': 80, 'order': 9, 'title': 'Киевская'}],
#     'pos': {'lat': '37.568102', 'lng': '55.743923'}}]},
#  {'id': 5,
#   'number': '06',
#   'title': 'Калужско-Рижская линия',
#   'hexColor': 'ED9121',
#   'stations': [{'id': 96,
#     'order': 0,
#     'title': 'Медведково',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.661527', 'lng': '55.887473'}},
#    {'id': 97,
#     'order': 1,
#     'title': 'Бабушкинская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.664464', 'lng': '55.869556'}},
#    {'id': 98,
#     'order': 2,
#     'title': 'Свиблово',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.652238', 'lng': '55.855224'}},
#    {'id': 99,
#     'order': 3,
#     'title': 'Ботанический сад',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Ботанический сад Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 245,
#       'order': 2,
#       'title': 'Ботанический сад'}],
#     'pos': {'lat': '37.637919', 'lng': '55.845228'}},
#    {'id': 100,
#     'order': 4,
#     'title': 'ВДНХ',
#     'transferToLine': [{'number': '13',
#       'str': 'Переход на станцию Выставочный центр Московского монорельса',
#       'title': 'Московский монорельс'}],
#     'transferToStation': [{'id': 241,
#       'order': 4,
#       'title': 'Выставочный центр'}],
#     'pos': {'lat': '37.641036', 'lng': '55.821097'}},
#    {'id': 101,
#     'order': 5,
#     'title': 'Алексеевская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.638737', 'lng': '55.8078'}},
#    {'id': 102,
#     'order': 6,
#     'title': 'Проспект Мира',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Проспект Мира Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 91, 'order': 7, 'title': 'Проспект Мира'}],
#     'pos': {'lat': '37.633023', 'lng': '55.781742'}},
#    {'id': 103,
#     'order': 7,
#     'title': 'Сухаревская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.632305', 'lng': '55.772492'}},
#    {'id': 104,
#     'order': 8,
#     'title': 'Тургеневская',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Чистые пруды Сокольнической линии',
#       'title': 'Сокольническая линия'},
#      {'number': '10',
#       'str': 'Переход на станцию Сретенский бульвар Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 7, 'order': 7, 'title': 'Чистые пруды'},
#      {'id': 195, 'order': 9, 'title': 'Сретенский бульвар'}],
#     'pos': {'lat': '37.636751', 'lng': '55.765235'}},
#    {'id': 105,
#     'order': 9,
#     'title': 'Китай-город',
#     'transferToLine': [{'number': '07',
#       'str': 'Кросс-платформенная пересадка на станцию Китай-город Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 131, 'order': 12, 'title': 'Китай-город'}],
#     'pos': {'lat': '37.631388', 'lng': '55.756548'}},
#    {'id': 106,
#     'order': 10,
#     'title': 'Третьяковская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Новокузнецкая Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'},
#      {'number': '08',
#       'str': 'Кросс-платформенная пересадка на станцию Третьяковская Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 38, 'order': 12, 'title': 'Новокузнецкая'},
#      {'id': 153, 'order': 0, 'title': 'Третьяковская'}],
#     'pos': {'lat': '37.626412', 'lng': '55.741348'}},
#    {'id': 107,
#     'order': 11,
#     'title': 'Октябрьская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Октябрьская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 85, 'order': 1, 'title': 'Октябрьская'}],
#     'pos': {'lat': '37.612461', 'lng': '55.731065'}},
#    {'id': 108,
#     'order': 12,
#     'title': 'Шаболовская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.607924', 'lng': '55.718816'}},
#    {'id': 109,
#     'order': 13,
#     'title': 'Ленинский проспект',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Площадь Гагарина Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 262,
#       'order': 19,
#       'title': 'Площадь Гагарина'}],
#     'pos': {'lat': '37.585583', 'lng': '55.707202'}},
#    {'id': 110,
#     'order': 14,
#     'title': 'Академическая',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.573447', 'lng': '55.687761'}},
#    {'id': 111,
#     'order': 15,
#     'title': 'Профсоюзная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.562874', 'lng': '55.67793'}},
#    {'id': 112,
#     'order': 16,
#     'title': 'Новые Черёмушки',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.554493', 'lng': '55.670077'}},
#    {'id': 113,
#     'order': 17,
#     'title': 'Калужская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.540075', 'lng': '55.656682'}},
#    {'id': 114,
#     'order': 18,
#     'title': 'Беляево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.525827', 'lng': '55.642748'}},
#    {'id': 115,
#     'order': 19,
#     'title': 'Коньково',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.519009', 'lng': '55.63315'}},
#    {'id': 116,
#     'order': 20,
#     'title': 'Тёплый Стан',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.506541', 'lng': '55.618644'}},
#    {'id': 117,
#     'order': 21,
#     'title': 'Ясенево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.5334', 'lng': '55.606182'}},
#    {'id': 118,
#     'order': 22,
#     'title': 'Новоясеневская',
#     'transferToLine': [{'number': '12',
#       'str': 'Переход на станцию Битцевский парк Бутовской линии',
#       'title': 'Бутовская линия'}],
#     'transferToStation': [{'id': 220, 'order': 0, 'title': 'Битцевский парк'}],
#     'pos': {'lat': '37.553828', 'lng': '55.601717'}}]},
#  {'id': 6,
#   'number': '07',
#   'title': 'Таганско-Краснопресненская линия',
#   'hexColor': '800080',
#   'stations': [{'id': 119,
#     'order': 0,
#     'title': 'Планерная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.4364', 'lng': '55.860923'}},
#    {'id': 120,
#     'order': 1,
#     'title': 'Сходненская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.439526', 'lng': '55.850515'}},
#    {'id': 121,
#     'order': 2,
#     'title': 'Тушинская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.437307', 'lng': '55.826417'}},
#    {'id': 122,
#     'order': 3,
#     'title': 'Спартак',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.43525', 'lng': '55.818098'}},
#    {'id': 123,
#     'order': 4,
#     'title': 'Щукинская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.463772', 'lng': '55.808827'}},
#    {'id': 124,
#     'order': 5,
#     'title': 'Октябрьское Поле',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Панфиловская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'},
#      {'number': '14',
#       'str': 'Переход на станцию Зорге Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 269, 'order': 26, 'title': 'Панфиловская'},
#      {'id': 268, 'order': 25, 'title': 'Зорге'}],
#     'pos': {'lat': '37.493317', 'lng': '55.793581'}},
#    {'id': 125,
#     'order': 6,
#     'title': 'Полежаевская',
#     'transferToLine': [{'number': '8А',
#       'str': 'Переход на станцию Хорошёвская Солнцевской линии',
#       'title': 'Солнцевская линия'},
#      {'number': '11',
#       'str': 'Переход на станцию Хорошёвская Большой кольцевой линии',
#       'title': 'Большая кольцевая линия'},
#      {'number': '14',
#       'str': 'Переход на станцию Хорошёво Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 212, 'order': 12, 'title': 'Хорошёвская'},
#      {'id': 213, 'order': 2, 'title': 'Хорошёвская'},
#      {'id': 267, 'order': 24, 'title': 'Хорошёво'}],
#     'pos': {'lat': '37.519315', 'lng': '55.777444'}},
#    {'id': 126,
#     'order': 7,
#     'title': 'Беговая',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.546291', 'lng': '55.773651'}},
#    {'id': 127,
#     'order': 8,
#     'title': 'Улица 1905 года',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.561392', 'lng': '55.764754'}},
#    {'id': 128,
#     'order': 9,
#     'title': 'Баррикадная',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Краснопресненская Кольцевой линии',
#       'title': 'Кольцевая линия'}],
#     'transferToStation': [{'id': 94,
#       'order': 10,
#       'title': 'Краснопресненская'}],
#     'pos': {'lat': '37.58128', 'lng': '55.760818'}},
#    {'id': 129,
#     'order': 10,
#     'title': 'Пушкинская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Тверская Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'},
#      {'number': '09',
#       'str': 'Переход на станцию Чеховская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 36, 'order': 10, 'title': 'Тверская'},
#      {'id': 171, 'order': 10, 'title': 'Чеховская'}],
#     'pos': {'lat': '37.6039', 'lng': '55.765747'}},
#    {'id': 130,
#     'order': 11,
#     'title': 'Кузнецкий Мост',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Лубянка Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 8, 'order': 8, 'title': 'Лубянка'}],
#     'pos': {'lat': '37.624516', 'lng': '55.761507'}},
#    {'id': 131,
#     'order': 12,
#     'title': 'Китай-город',
#     'transferToLine': [{'number': '06',
#       'str': 'Кросс-платформенная пересадка на станцию Китай-город Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 105, 'order': 9, 'title': 'Китай-город'}],
#     'pos': {'lat': '37.633877', 'lng': '55.75436'}},
#    {'id': 132,
#     'order': 13,
#     'title': 'Таганская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Таганская Кольцевой линии',
#       'title': 'Кольцевая линия'},
#      {'number': '08',
#       'str': 'Переход на станцию Марксистская Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 88, 'order': 4, 'title': 'Таганская'},
#      {'id': 154, 'order': 1, 'title': 'Марксистская'}],
#     'pos': {'lat': '37.652957', 'lng': '55.739544'}},
#    {'id': 133,
#     'order': 14,
#     'title': 'Пролетарская',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Крестьянская застава Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 198,
#       'order': 12,
#       'title': 'Крестьянская застава'}],
#     'pos': {'lat': '37.666162', 'lng': '55.731673'}},
#    {'id': 134,
#     'order': 15,
#     'title': 'Волгоградский проспект',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Угрешская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 256, 'order': 13, 'title': 'Угрешская'}],
#     'pos': {'lat': '37.687084', 'lng': '55.724976'}},
#    {'id': 135,
#     'order': 16,
#     'title': 'Текстильщики',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.732593', 'lng': '55.708831'}},
#    {'id': 136,
#     'order': 17,
#     'title': 'Кузьминки',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.766145', 'lng': '55.705463'}},
#    {'id': 137,
#     'order': 18,
#     'title': 'Рязанский проспект',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.793606', 'lng': '55.717366'}},
#    {'id': 138,
#     'order': 19,
#     'title': 'Выхино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.81804', 'lng': '55.715601'}},
#    {'id': 139,
#     'order': 20,
#     'title': 'Лермонтовский проспект',
#     'transferToLine': [{'number': '15',
#       'str': 'Переход на станцию Косино Некрасовской линии',
#       'title': 'Некрасовская линия'}],
#     'transferToStation': [{'id': 233, 'order': 6, 'title': 'Косино'}],
#     'pos': {'lat': '37.852374', 'lng': '55.701699'}},
#    {'id': 140,
#     'order': 21,
#     'title': 'Жулебино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.855797', 'lng': '55.685132'}},
#    {'id': 141,
#     'order': 22,
#     'title': 'Котельники',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.858635', 'lng': '55.674133'}}]},
#  {'id': 7,
#   'number': '8А',
#   'title': 'Солнцевская линия',
#   'hexColor': 'FFD702',
#   'stations': [{'id': 142,
#     'order': 0,
#     'title': 'Рассказовка',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.334747', 'lng': '55.633968'}},
#    {'id': 143,
#     'order': 1,
#     'title': 'Новопеределкино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.355228', 'lng': '55.639613'}},
#    {'id': 144,
#     'order': 2,
#     'title': 'Боровское шоссе',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.370122', 'lng': '55.647671'}},
#    {'id': 145,
#     'order': 3,
#     'title': 'Солнцево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.3909', 'lng': '55.649383'}},
#    {'id': 146,
#     'order': 4,
#     'title': 'Говорово',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.417266', 'lng': '55.659551'}},
#    {'id': 147,
#     'order': 5,
#     'title': 'Озёрная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.449003', 'lng': '55.670574'}},
#    {'id': 148,
#     'order': 6,
#     'title': 'Мичуринский проспект',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.482969', 'lng': '55.689456'}},
#    {'id': 149,
#     'order': 7,
#     'title': 'Раменки',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.498725', 'lng': '55.697691'}},
#    {'id': 150,
#     'order': 8,
#     'title': 'Ломоносовский проспект',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.516063', 'lng': '55.70706'}},
#    {'id': 151,
#     'order': 9,
#     'title': 'Минская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.497872', 'lng': '55.723947'}},
#    {'id': 152,
#     'order': 10,
#     'title': 'Парк Победы',
#     'transferToLine': [{'number': '03',
#       'str': 'Кросс-платформенная пересадка на станцию Парк Победы Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'}],
#     'transferToStation': [{'id': 59, 'order': 9, 'title': 'Парк Победы'}],
#     'pos': {'lat': '37.516979', 'lng': '55.736169'}},
#    {'id': 210,
#     'order': 11,
#     'title': 'Шелепиха',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Шелепиха Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 266, 'order': 23, 'title': 'Шелепиха'}],
#     'pos': {'lat': '37.524067', 'lng': '55.757116'}},
#    {'id': 212,
#     'order': 12,
#     'title': 'Хорошёвская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Полежаевская Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'},
#      {'number': '14',
#       'str': 'Переход на станцию Хорошёво Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 125, 'order': 6, 'title': 'Полежаевская'},
#      {'id': 267, 'order': 24, 'title': 'Хорошёво'}],
#     'pos': {'lat': '37.520797', 'lng': '55.776862'}},
#    {'id': 214,
#     'order': 13,
#     'title': 'ЦСКА',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.533301', 'lng': '55.786602'}},
#    {'id': 216,
#     'order': 14,
#     'title': 'Петровский парк',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Динамо Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 33, 'order': 7, 'title': 'Динамо'}],
#     'pos': {'lat': '37.557188', 'lng': '55.791845'}},
#    {'id': 218,
#     'order': 15,
#     'title': 'Савёловская',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Савёловская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 168, 'order': 7, 'title': 'Савёловская'}],
#     'pos': {'lat': '37.586122', 'lng': '55.792807'}}]},
#  {'id': 8,
#   'number': '08',
#   'title': 'Калининская линия',
#   'hexColor': 'FFD702',
#   'stations': [{'id': 153,
#     'order': 0,
#     'title': 'Третьяковская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Новокузнецкая Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'},
#      {'number': '06',
#       'str': 'Кросс-платформенная пересадка на станцию Третьяковская Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 38, 'order': 12, 'title': 'Новокузнецкая'},
#      {'id': 106, 'order': 10, 'title': 'Третьяковская'}],
#     'pos': {'lat': '37.626412', 'lng': '55.741348'}},
#    {'id': 154,
#     'order': 1,
#     'title': 'Марксистская',
#     'transferToLine': [{'number': '05',
#       'str': 'Переход на станцию Таганская Кольцевой линии',
#       'title': 'Кольцевая линия'},
#      {'number': '07',
#       'str': 'Переход на станцию Таганская Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 88, 'order': 4, 'title': 'Таганская'},
#      {'id': 132, 'order': 13, 'title': 'Таганская'}],
#     'pos': {'lat': '37.655957', 'lng': '55.741303'}},
#    {'id': 155,
#     'order': 2,
#     'title': 'Площадь Ильича',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Римская Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 197, 'order': 11, 'title': 'Римская'}],
#     'pos': {'lat': '37.680949', 'lng': '55.747069'}},
#    {'id': 156,
#     'order': 3,
#     'title': 'Авиамоторная',
#     'transferToLine': [{'number': '15',
#       'str': 'Переход на станцию Авиамоторная Некрасовской линии',
#       'title': 'Некрасовская линия'}],
#     'transferToStation': [{'id': 228, 'order': 1, 'title': 'Авиамоторная'}],
#     'pos': {'lat': '37.716612', 'lng': '55.751432'}},
#    {'id': 157,
#     'order': 4,
#     'title': 'Шоссе Энтузиастов',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Шоссе Энтузиастов Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 252,
#       'order': 9,
#       'title': 'Шоссе Энтузиастов'}],
#     'pos': {'lat': '37.751538', 'lng': '55.758407'}},
#    {'id': 158,
#     'order': 5,
#     'title': 'Перово',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.786887', 'lng': '55.75132'}},
#    {'id': 159,
#     'order': 6,
#     'title': 'Новогиреево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.817169', 'lng': '55.75166'}},
#    {'id': 160,
#     'order': 7,
#     'title': 'Новокосино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.864052', 'lng': '55.745113'}}]},
#  {'id': 9,
#   'number': '09',
#   'title': 'Серпуховско-Тимирязевская линия',
#   'hexColor': '999999',
#   'stations': [{'id': 161,
#     'order': 0,
#     'title': 'Алтуфьево',
# ...
#     'pos': {'lat': '37.586122', 'lng': '55.792807'}}]},
#  {'id': 12,
#   'number': '12',
#   'title': 'Бутовская линия',
#   'hexColor': 'A1B3D4',
#   'stations': [{'id': 220,
#     'order': 0,
#     'title': 'Битцевский парк',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Новоясеневская Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 118, 'order': 22, 'title': 'Новоясеневская'}],
#     'pos': {'lat': '37.556451', 'lng': '55.600257'}},
#    {'id': 221,
#     'order': 1,
#     'title': 'Лесопарковая',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.57731', 'lng': '55.581968'}},
#    {'id': 222,
#     'order': 2,
#     'title': 'Улица Старокачаловская',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Бульвар Дмитрия Донского Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 185,
#       'order': 24,
#       'title': 'Бульвар Дмитрия Донского'}],
#     'pos': {'lat': '37.576403', 'lng': '55.568425'}},
#    {'id': 223,
#     'order': 3,
#     'title': 'Улица Скобелевская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.554636', 'lng': '55.548044'}},
#    {'id': 224,
#     'order': 4,
#     'title': 'Бульвар Адмирала Ушакова',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.542833', 'lng': '55.545319'}},
#    {'id': 225,
#     'order': 5,
#     'title': 'Улица Горчакова',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.531514', 'lng': '55.541932'}},
#    {'id': 226,
#     'order': 6,
#     'title': 'Бунинская аллея',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.515919', 'lng': '55.537964'}}]},
#  {'id': 13,
#   'number': '15',
#   'title': 'Некрасовская линия',
#   'hexColor': 'DE64A1',
#   'stations': [{'id': 227,
#     'order': 0,
#     'title': 'Лефортово',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.706757', 'lng': '55.764693'}},
#    {'id': 228,
#     'order': 1,
#     'title': 'Авиамоторная',
#     'transferToLine': [{'number': '08',
#       'str': 'Переход на станцию Авиамоторная Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 156, 'order': 3, 'title': 'Авиамоторная'}],
#     'pos': {'lat': '37.719154', 'lng': '55.753666'}},
#    {'id': 229,
#     'order': 2,
#     'title': 'Нижегородская',
#     'transferToLine': [{'number': '14',
#       'str': 'Переход на станцию Нижегородская Московского центрального кольца',
#       'title': 'Московское центральное кольцо'}],
#     'transferToStation': [{'id': 254, 'order': 11, 'title': 'Нижегородская'}],
#     'pos': {'lat': '37.730311', 'lng': '55.731678'}},
#    {'id': 230,
#     'order': 3,
#     'title': 'Стахановская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.752257', 'lng': '55.727207'}},
#    {'id': 231,
#     'order': 4,
#     'title': 'Окская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.781272', 'lng': '55.718623'}},
#    {'id': 232,
#     'order': 5,
#     'title': 'Юго-Восточная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.817995', 'lng': '55.705351'}},
#    {'id': 233,
#     'order': 6,
#     'title': 'Косино',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Лермонтовский проспект Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 139,
#       'order': 20,
#       'title': 'Лермонтовский проспект'}],
#     'pos': {'lat': '37.851305', 'lng': '55.703423'}},
#    {'id': 234,
#     'order': 7,
#     'title': 'Улица Дмитриевского',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.879045', 'lng': '55.710311'}},
#    {'id': 235,
#     'order': 8,
#     'title': 'Лухмановская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.900569', 'lng': '55.708516'}},
#    {'id': 236,
#     'order': 9,
#     'title': 'Некрасовка',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.92803', 'lng': '55.702967'}}]},
#  {'id': 14,
#   'number': '13',
#   'title': 'Московский монорельс',
#   'hexColor': '9999FF',
#   'stations': [{'id': 237,
#     'order': 0,
#     'title': 'Тимирязевская',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Тимирязевская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 166, 'order': 5, 'title': 'Тимирязевская'}],
#     'pos': {'lat': '37.575271', 'lng': '55.818695'}},
#    {'id': 238,
#     'order': 1,
#     'title': 'Улица Милашенкова',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Фонвизинская Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 190, 'order': 4, 'title': 'Фонвизинская'}],
#     'pos': {'lat': '37.591207', 'lng': '55.821876'}},
#    {'id': 239,
#     'order': 2,
#     'title': 'Телецентр',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.608975', 'lng': '55.821795'}},
#    {'id': 240,
#     'order': 3,
#     'title': 'Улица Академика Королёва',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.627166', 'lng': '55.821821'}},
#    {'id': 241,
#     'order': 4,
#     'title': 'Выставочный центр',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию ВДНХ Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 100, 'order': 4, 'title': 'ВДНХ'}],
#     'pos': {'lat': '37.638494', 'lng': '55.824086'}},
#    {'id': 242,
#     'order': 5,
#     'title': 'Улица Сергея Эйзенштейна',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.644998', 'lng': '55.829305'}}]},
#  {'id': 15,
#   'number': '14',
#   'title': 'Московское центральное кольцо',
#   'hexColor': 'FFFFFF',
#   'stations': [{'id': 243,
#     'order': 0,
#     'title': 'Окружная',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Окружная Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 188, 'order': 2, 'title': 'Окружная'}],
#     'pos': {'lat': '37.572136', 'lng': '55.848756'}},
#    {'id': 244,
#     'order': 1,
#     'title': 'Владыкино',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Владыкино Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 164, 'order': 3, 'title': 'Владыкино'}],
#     'pos': {'lat': '37.59038', 'lng': '55.847978'}},
#    {'id': 245,
#     'order': 2,
#     'title': 'Ботанический сад',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Ботанический сад Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 99, 'order': 3, 'title': 'Ботанический сад'}],
#     'pos': {'lat': '37.637919', 'lng': '55.845228'}},
#    {'id': 246,
#     'order': 3,
#     'title': 'Ростокино',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.668399', 'lng': '55.839224'}},
#    {'id': 247,
#     'order': 4,
#     'title': 'Белокаменная',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.70231', 'lng': '55.829375'}},
#    {'id': 248,
#     'order': 5,
#     'title': 'Бульвар Рокоссовского',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Бульвар Рокоссовского Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 0,
#       'order': 0,
#       'title': 'Бульвар Рокоссовского'}],
#     'pos': {'lat': '37.735117', 'lng': '55.814264'}},
#    {'id': 249,
#     'order': 6,
#     'title': 'Локомотив',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Черкизовская Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 1, 'order': 1, 'title': 'Черкизовская'}],
#     'pos': {'lat': '37.746058', 'lng': '55.80313'}},
#    {'id': 250,
#     'order': 7,
#     'title': 'Измайлово',
#     'transferToLine': [{'number': '03',
#       'str': 'Переход на станцию Партизанская Арбатско-Покровской линии',
#       'title': 'Арбатско-Покровская линия'}],
#     'transferToStation': [{'id': 67, 'order': 17, 'title': 'Партизанская'}],
#     'pos': {'lat': '37.743031', 'lng': '55.788409'}},
#    {'id': 251,
#     'order': 8,
#     'title': 'Соколиная Гора',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.745385', 'lng': '55.769914'}},
#    {'id': 252,
#     'order': 9,
#     'title': 'Шоссе Энтузиастов',
#     'transferToLine': [{'number': '08',
#       'str': 'Переход на станцию Шоссе Энтузиастов Калининской линии',
#       'title': 'Калининская линия'}],
#     'transferToStation': [{'id': 157,
#       'order': 4,
#       'title': 'Шоссе Энтузиастов'}],
#     'pos': {'lat': '37.751538', 'lng': '55.758407'}},
#    {'id': 253,
#     'order': 10,
#     'title': 'Андроновка',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.736842', 'lng': '55.746319'}},
#    {'id': 254,
#     'order': 11,
#     'title': 'Нижегородская',
#     'transferToLine': [{'number': '15',
#       'str': 'Переход на станцию Нижегородская Некрасовской линии',
#       'title': 'Некрасовская линия'}],
#     'transferToStation': [{'id': 229, 'order': 2, 'title': 'Нижегородская'}],
#     'pos': {'lat': '37.728326', 'lng': '55.732469'}},
#    {'id': 255,
#     'order': 12,
#     'title': 'Новохохловская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.716737', 'lng': '55.724084'}},
#    {'id': 256,
#     'order': 13,
#     'title': 'Угрешская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Волгоградский проспект Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 134,
#       'order': 15,
#       'title': 'Волгоградский проспект'}],
#     'pos': {'lat': '37.695555', 'lng': '55.717944'}},
#    {'id': 257,
#     'order': 14,
#     'title': 'Дубровка',
#     'transferToLine': [{'number': '10',
#       'str': 'Переход на станцию Дубровка Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'},
#      {'number': '10',
#       'str': 'Переход на станцию Кожуховская Люблинско-Дмитровской линии',
#       'title': 'Люблинско-Дмитровская линия'}],
#     'transferToStation': [{'id': 199, 'order': 13, 'title': 'Дубровка'},
#      {'id': 200, 'order': 14, 'title': 'Кожуховская'}],
#     'pos': {'lat': '37.676241', 'lng': '55.71807'}},
#    {'id': 258,
#     'order': 15,
#     'title': 'Автозаводская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Автозаводская Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 40, 'order': 14, 'title': 'Автозаводская'}],
#     'pos': {'lat': '37.657646', 'lng': '55.707182'}},
#    {'id': 259,
#     'order': 16,
#     'title': 'ЗИЛ',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.649265', 'lng': '55.698665'}},
#    {'id': 260,
#     'order': 17,
#     'title': 'Верхние Котлы',
#     'transferToLine': [{'number': '09',
#       'str': 'Переход на станцию Нагатинская Серпуховско-Тимирязевской линии',
#       'title': 'Серпуховско-Тимирязевская линия'}],
#     'transferToStation': [{'id': 176, 'order': 15, 'title': 'Нагатинская'}],
#     'pos': {'lat': '37.618758', 'lng': '55.69008'}},
#    {'id': 261,
#     'order': 18,
#     'title': 'Крымская',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.605122', 'lng': '55.689999'}},
#    {'id': 262,
#     'order': 19,
#     'title': 'Площадь Гагарина',
#     'transferToLine': [{'number': '06',
#       'str': 'Переход на станцию Ленинский проспект Калужско-Рижской линии',
#       'title': 'Калужско-Рижская линия'}],
#     'transferToStation': [{'id': 109,
#       'order': 13,
#       'title': 'Ленинский проспект'}],
#     'pos': {'lat': '37.58658', 'lng': '55.706771'}},
#    {'id': 263,
#     'order': 20,
#     'title': 'Лужники',
#     'transferToLine': [{'number': '01',
#       'str': 'Переход на станцию Спортивная Сокольнической линии',
#       'title': 'Сокольническая линия'}],
#     'transferToStation': [{'id': 14, 'order': 14, 'title': 'Спортивная'}],
#     'pos': {'lat': '37.56035', 'lng': '55.720859'}},
#    {'id': 264,
#     'order': 21,
#     'title': 'Кутузовская',
#     'transferToLine': [{'number': '04',
#       'str': 'Переход на станцию Кутузовская Филёвской линии',
#       'title': 'Филёвская линия'}],
#     'transferToStation': [{'id': 76, 'order': 5, 'title': 'Кутузовская'}],
#     'pos': {'lat': '37.534191', 'lng': '55.74033'}},
#    {'id': 265,
#     'order': 22,
#     'title': 'Деловой центр',
#     'transferToLine': [{'number': '04',
#       'str': 'Переход на станцию Международная Филёвской линии',
#       'title': 'Филёвская линия'}],
#     'transferToStation': [{'id': 78, 'order': 7, 'title': 'Международная'}],
#     'pos': {'lat': '37.539904', 'lng': '55.749025'}},
#    {'id': 266,
#     'order': 23,
#     'title': 'Шелепиха',
#     'transferToLine': [{'number': '8А',
#       'str': 'Переход на станцию Шелепиха Солнцевской линии',
#       'title': 'Солнцевская линия'},
#      {'number': '11',
#       'str': 'Переход на станцию Шелепиха Большой кольцевой линии',
#       'title': 'Большая кольцевая линия'}],
#     'transferToStation': [{'id': 210, 'order': 11, 'title': 'Шелепиха'},
#      {'id': 211, 'order': 1, 'title': 'Шелепиха'}],
#     'pos': {'lat': '37.526043', 'lng': '55.756786'}},
#    {'id': 267,
#     'order': 24,
#     'title': 'Хорошёво',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Полежаевская Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'},
#      {'number': '8А',
#       'str': 'Переход на станцию Хорошёвская Солнцевской линии',
#       'title': 'Солнцевская линия'},
#      {'number': '11',
#       'str': 'Переход на станцию Хорошёвская Большой кольцевой линии',
#       'title': 'Большая кольцевая линия'}],
#     'transferToStation': [{'id': 125, 'order': 6, 'title': 'Полежаевская'},
#      {'id': 212, 'order': 12, 'title': 'Хорошёвская'},
#      {'id': 213, 'order': 2, 'title': 'Хорошёвская'}],
#     'pos': {'lat': '37.507493', 'lng': '55.776917'}},
#    {'id': 268,
#     'order': 25,
#     'title': 'Зорге',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Октябрьское Поле Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 124,
#       'order': 5,
#       'title': 'Октябрьское Поле'}],
#     'pos': {'lat': '37.504214', 'lng': '55.789153'}},
#    {'id': 269,
#     'order': 26,
#     'title': 'Панфиловская',
#     'transferToLine': [{'number': '07',
#       'str': 'Переход на станцию Октябрьское Поле Таганско-Краснопресненской линии',
#       'title': 'Таганско-Краснопресненская линия'}],
#     'transferToStation': [{'id': 124,
#       'order': 5,
#       'title': 'Октябрьское Поле'}],
#     'pos': {'lat': '37.499821', 'lng': '55.798019'}},
#    {'id': 270,
#     'order': 27,
#     'title': 'Стрешнево',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Войковская Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 30, 'order': 4, 'title': 'Войковская'}],
#     'pos': {'lat': '37.486966', 'lng': '55.813698'}},
#    {'id': 271,
#     'order': 28,
#     'title': 'Балтийская',
#     'transferToLine': [{'number': '02',
#       'str': 'Переход на станцию Войковская Замоскворецкой линии',
#       'title': 'Замоскворецкая линия'}],
#     'transferToStation': [{'id': 30, 'order': 4, 'title': 'Войковская'}],
#     'pos': {'lat': '37.494728', 'lng': '55.825148'}},
#    {'id': 272,
#     'order': 29,
#     'title': 'Коптево',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.521417', 'lng': '55.840452'}},
#    {'id': 273,
#     'order': 30,
#     'title': 'Лихоборы',
#     'transferToLine': [],
#     'transferToStation': [],
#     'pos': {'lat': '37.553037', 'lng': '55.847669'}}]}]

# %%
f = open('preferences.json', 'r')
preferences = json.load(f)['preferences']
f.close()
preferences
# Out:
# [{'drink': 'Кофе', 'station': 'Сокол', 'name': 'Воробьева Арина'},
#  {'drink': 'Чай', 'station': 'Маяковская', 'name': 'Олейников Иван'},
#  {'drink': 'Кофе', 'station': 'Речной вокзал', 'name': 'Макарова Анна'},
#  {'drink': 'Чай', 'station': 'Белорусская', 'name': 'Романадзе Екатерина'},
#  {'drink': 'Кофе', 'station': 'Речной вокзал', 'name': 'Иванов Андрей'},
#  {'drink': 'Чай', 'station': 'Беломорская', 'name': 'Еремеев Даниил'},
#  {'drink': 'Кофе', 'station': 'Сходненская', 'name': 'Лебедев Евгений'},
#  {'drink': 'Чай', 'station': 'Пражская', 'name': 'Мирзагаламов Ринат'},
#  {'drink': 'Чай', 'station': 'Юго-Западная', 'name': 'Мохов Алексей'},
#  {'drink': 'Кофе', 'station': 'Калужская', 'name': 'Чернева Надежда'}]

# %%
preference_data = {}

for preference in preferences:
    if preference_data.get(preference['station']):
        if preference['drink'] == 'Кофе':
            preference_data[preference['station']] += 1
        else:
            preference_data[preference['station']] += -1
    else:
        if preference['drink'] == 'Кофе':
            preference_data[preference['station']] = 1
        else:
            preference_data[preference['station']] = -1
            
preference_data
# Out:
# {'Сокол': 1,
#  'Маяковская': -1,
#  'Речной вокзал': 2,
#  'Белорусская': -1,
#  'Беломорская': -1,
#  'Сходненская': 1,
#  'Пражская': -1,
#  'Юго-Западная': -1,
#  'Калужская': 1}

# %%
class Station:
    def __init__(self,
                 line_id,
                 line_number,
                 line_title,
                 color,
                 id,
                 order,
                 title,
                 pos,
                 next,
                 drink_summ):
        self.line_id = line_id
        self.line_number = line_number
        self.line_title = line_title
        self.color = color
        self.id = id
        self.order = order
        self.title = title
        self.pos = pos
        self.next = next
        self.drink_summ = drink_summ
        self.transfer_to_stations = []
        
    def add_transfer_to_stations(self, transfer_to_stations):
        for transfer in transfer_to_stations:
            self.transfer_to_stations.append(transfer['id'])

# %%
stations = []

for i in range(len(lines)):
    line = lines[i]
    for j in range(len(line['stations'])):
        station = line['stations'][j]
        
        if preference_data.get(station['title']):
            drink_summ = preference_data.pop(station['title'])
#             drink_summ = preference_data.get(station['title'])
        else:
            drink_summ = 0
            
        if station['order'] != len(line['stations']) - 1:
            station['next'] = line['stations'][j + 1]['id']
        elif line['title'] == 'Кольцевая линия' or line['title'] == 'Московское центральное кольцо':
            station['next'] =  line['stations'][0]['id']
        else:
            station['next'] = None
            
        new_station = Station(line['id'],
                              line['number'],
                              line['title'],
                              line['hexColor'],
                              station['id'],
                              station['order'],
                              station['title'],
                              station['pos'],
                              station['next'],
                              drink_summ)
        
        new_station.add_transfer_to_stations(station['transferToStation'])
        stations.append(new_station)
        
stations = sorted(stations, key=lambda station: station.id)

# %%
lines = []
created_lines = set()
for station in sorted(stations, key=lambda station: station.line_id):
    if not station.line_id in created_lines:
        created_lines.add(station.line_id)
        lines.append({'title': station.line_title, 'color': station.color, 'stations': []})
    lines[len(created_lines) - 1]['stations'].append(station)

# %%
def get_stations_by_title(station_title):
    stations_by_name = []
    
    for station in stations:
        if station.title.lower() == station_title.lower():
            stations_by_name.append(station)
            
    if len(stations) == 0:
        return 'Станции с таким названием нет'
    else:
        return stations_by_name

# %%
def get_station_by_title_and_line(station_title, line_title):
    for station in stations:
        if station.title.lower() == station_title.lower() and station.line_title == line_title:
            return station
    
    return 'Такой станции не существует'

# %%
def calc_distance(pos_A, pos_B):
    EARTH_RADIUS = 6372.795
    
    lat_A = float(pos_A['lat']) * math.pi / 180
    lat_B = float(pos_B['lat']) * math.pi / 180
    lng_A = float(pos_A['lng']) * math.pi / 180
    lng_B = float(pos_B['lng']) * math.pi / 180
    
    a = math.sin(lat_A)*math.sin(lat_B) + math.cos(lat_A)*math.cos(lat_B)*math.cos(lng_B- lng_A)
    a = a if a <= 1 else 1
    
    distance = EARTH_RADIUS * math.acos(a)
    return distance

# %%
def draw_map(stations_to_be_highlighted=None, show_stations_with_drink_preferences=False):
    fig, ax = plt.subplots(figsize=(14, 14))
    stations_with_drink_preferences = set()
    
    for line in lines:
        x = []
        y = []

        for station in line['stations']:
            x.append(float(station.pos['lat']))
            y.append(float(station.pos['lng']))
            
            if station.drink_summ != 0 and show_stations_with_drink_preferences:
                stations_with_drink_preferences.add(station)

        color = line['color']
        if line['title'] == 'Кольцевая линия' or line['title'] == 'Московское центральное кольцо':
            x.append(x[0])
            y.append(y[0])

        if line['title'] == 'Московское центральное кольцо':
            ax.plot(x, y, marker='o', c='#' + color, markeredgecolor='r',
                    path_effects=[pe.Stroke(linewidth=2, foreground='r'), pe.Normal()])
        else:
            ax.plot(x, y, marker='o', c='#' + color)
            
    if show_stations_with_drink_preferences:
        x = []
        y = []
             
        for station in stations_with_drink_preferences:
            x.append(float(station.pos['lat']))
            y.append(float(station.pos['lng']))
        
        ax.scatter(x, y, s=200, marker='*', c='white', edgecolor='black', zorder=9, label='Значимые станции с напитками')
        
    if stations_to_be_highlighted:
        x = []
        y = []
             
        for station_id in stations_to_be_highlighted:
            x.append(float(stations[station_id].pos['lat']))
            y.append(float(stations[station_id].pos['lng']))
        
        ax.scatter(x, y, s=200, marker='X', c='white', edgecolor='black', zorder=10, label='Достижимые станции')
    

    ax.set_title('Карта метро')
    ax.set_xlabel('Широта')
    ax.set_ylabel('Долгота')
    ax.legend(loc='upper left')

# %%
N = len(stations)
W = np.zeros((N, N))
R = np.zeros((N, N))

def matrix_filling(transfer_multiplier=1):
    for i in range(len(W)):
        for j in range(len(W[i])):
            if i != j:
                W[i][j] = np.inf

    for i in range(N):
        if stations[i].next != None:
            next = stations[i].next
            distance = calc_distance(stations[i].pos, stations[next].pos)
            W[i][next] = distance
            W[next][i] = distance
            R[i][next] = 1
            R[next][i] = 1

        if len(stations[i].transfer_to_stations) > 0:
            for station_id in stations[i].transfer_to_stations:
                W[i][station_id] = calc_distance(stations[i].pos, stations[station_id].pos) * transfer_multiplier
                W[station_id][i] = calc_distance(stations[i].pos, stations[station_id].pos) * transfer_multiplier
                R[i][station_id] = 1
                R[station_id][i] = 1
                
matrix_filling(transfer_multiplier=1)

# %%
D = W.copy()

def floyd_warshall():
    for i in range(N):
        for j in range(N):
            for k in range(N):
                if D[j][i] + D[i][k] < D[j][k]:
                    D[j][k] = D[j][i] + D[i][k]
                    
# %time floyd_warshall()
D
# Out:
# CPU times: user 23.5 s, sys: 43.8 ms, total: 23.5 s
# Wall time: 23.6 s
# array([[ 0.        ,  1.43481274,  4.82590506, ..., 27.47023865,
#         24.20903939, 20.63492848],
#        [ 1.43481274,  0.        ,  3.39109232, ..., 28.90505139,
#         25.64385213, 22.06974122],
#        [ 4.82590506,  3.39109232,  0.        , ..., 26.20750819,
#         26.69172478, 23.11761387],
#        ...,
#        [27.47023865, 28.90505139, 26.20750819, ...,  0.        ,
#          3.26119926,  6.83531017],
#        [24.20903939, 25.64385213, 26.69172478, ...,  3.26119926,
#          0.        ,  3.57411091],
#        [20.63492848, 22.06974122, 23.11761387, ...,  6.83531017,
#          3.57411091,  0.        ]])

# %%
f = open('distanceMatrix.json', 'w')
json.dump(D.tolist(), f, indent = 2)
f.close()

# %%
f = open('distanceMatrix.json', 'r')
D = json.load(f)
f.close()

# %%
def get_drink_preference(log=False, show_map=False):
    max_distance = 0
    drink_summ = 0
    choiced_station = None
    stations_within_max_distance = set()
    
    print('Введите название станции')
    station_title = input().strip()
    
    searched_stations = get_stations_by_title(station_title)
    if isinstance(searched_stations, str):
        return searched_stations
    
    if len(searched_stations) == 0:
        return 'Неправильное название станции'
    
    if len(searched_stations) == 1:
        choiced_station = searched_stations[0]
    else:
        print('Станций с таким названием: {}.'.format(len(searched_stations)))
        print('Введите номер нужной линии:')
        for index, station in enumerate(searched_stations):
            print('{}. {}'.format(index + 1, station.line_title))
            
        searched_line_number = int(input()) - 1
        choiced_station = get_station_by_title_and_line(station_title, searched_stations[searched_line_number].line_title)
        print('Вы выбрали: {} {}'.format(choiced_station.title, choiced_station.line_title))
    
    if choiced_station == None:
        return 'Неправильное название станции'
    
    while drink_summ == 0:
        if log:
            print(f"max_distance = {max_distance}km")
              
        for i in range(len(D[choiced_station.id])):
            if D[choiced_station.id][i] <= max_distance:
                stations_within_max_distance.add(i)
                
        for station_id in stations_within_max_distance:
            station = stations[station_id]
            drink_summ += station.drink_summ
            if log:
                print(station.title, station.drink_summ)
            
        max_distance += 1
        
        if max_distance == 133:
            break
            
    if show_map:
        draw_map(stations_to_be_highlighted=stations_within_max_distance, show_stations_with_drink_preferences=True)
            
    if drink_summ > 0:
        return 'Кофе'
    elif drink_summ < 0:
        return 'Чай'
    else:
        return 'Предпочтения в напитках равны'

# %%
get_drink_preference(log=True, show_map=True)
# Out:
# Введите название станции
# Пушкинская
# max_distance = 0km
# Пушкинская 0
# max_distance = 1km
# Пушкинская 0
# Чеховская 0
# Тверская 0
# max_distance = 2km
# Пушкинская 0
# Маяковская -1
# Тверская 0
# Театральная 0
# Библиотека имени Ленина 0
# Чеховская 0
# Цветной бульвар 0
# Боровицкая 0
# Александровский сад 0
# 'Чай'
